# %% [markdown]
# # From Prompts to Workflows
#
# In this notebook, we'll see why a single LLM prompt breaks down on multi-step tasks and how LangGraph provides **structure, state, and control flow** to fix it.

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
# Expects: OPENROUTER_API_KEY, SERPAPI_API_KEY
# Optional: LANGSMITH_API_KEY
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# We use OpenRouter as our LLM gateway — swap models by changing the model string
llm = ChatOpenAI(
    model="anthropic/claude-sonnet-4.6",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
)

# %% [markdown]
# ## Why single prompts break down
#
# Let's try asking a model to do three things in one shot:
# 1. Write a product description for a fictional AI tool
# 2. Critique the description for clarity, tone, and persuasiveness
# 3. Rewrite an improved version based on the critique
#
# This is a common pattern — you want a pipeline of steps, but you cram it all into one prompt.

# %%
# One prompt trying to do three things at once
response = llm.invoke(
    "Write a product description for a fictional AI-powered meeting assistant called 'MeetingMind'. "
    "Then critique the description for clarity, tone, and persuasiveness. "
    "Then rewrite an improved version based on the critique."
)
print(response.content)
# Out:
# # MeetingMind: Product Description Exercise
#
# ---
#
# ## DRAFT 1: Original Product Description
#
# **MeetingMind — Your AI-Powered Meeting Assistant**
#
# MeetingMind is an advanced artificial intelligence solution that leverages cutting-edge natural language processing algorithms to facilitate the optimization of your organizational meeting workflows. Utilizing state-of-the-art machine learning models, MeetingMind provides real-time transcription capabilities, action item extraction functionality, and automated summary generation for all of your professional meeting environments.
#
# MeetingMind integrates seamlessly with your existing tech stack, including popular platforms such as Zoom, Microsoft Teams, and Google Meet. The system employs sophisticated sentiment analysis to gauge participant engagement levels and delivers post-meeting analytics dashboards featuring granular productivity metrics.
#
# Users of MeetingMind will find that the product offers significant value-add propositions through its ability to reduce redundant manual note-taking processes, thereby enabling knowledge workers to allocate their cognitive bandwidth toward higher-priority strategic initiatives. The solution is highly scalable and enterprise-ready, offering robust security infrastructure compliant with industry-standard data protection frameworks.
#
# Try MeetingMind today and unlock the full potential of your meeting ecosystem.
#
# ---
#
# ## CRITIQUE
#
# ### 1. Clarity — **Grade: C+**
#
# **Problems identified:**
#
# - **Jargon overload** is the primary clarity killer. Phrases like *"leverages cutting-edge natural language processing algorithms,"* *"cognitive bandwidth,"* and *"meeting ecosystem"* are vague, buzzword-heavy, and communicate nothing concrete to the average reader.
# - **Feature descriptions are abstract.** "Action item extraction functionality" tells us *what it does* but never shows *what that means* for the user. Does it send you an email? Appear in a dashboard? Sync to Asana?
# - **The lead buries the value.** The first sentence is 38 words long and explains the technology before explaining the *benefit.* Most readers will disengage before understanding what the product actually does.
# - **Passive and nominalized constructions** ("facilitate the optimization of," "enabling knowledge workers to allocate") make sentences sluggish and harder to parse.
#
# ---
#
# ### 2. Tone — **Grade: C**
#
# **Problems identified:**
#
# - **Cold and corporate throughout.** The description reads like a B2B procurement document, not a product page meant to generate excitement or trust. There is no human warmth, no personality, and no acknowledgment of the *frustration* the product is solving.
# - **No voice or brand identity.** Any competitor could swap in their product name and this description would still technically fit. MeetingMind has no distinct personality.
# - **The call to action is flat and unconvincing.** *"Try MeetingMind today and unlock the full potential of your meeting ecosystem"* is generic, forgettable, and uses another meaningless abstraction ("meeting ecosystem").
# - **It talks *about* the user without talking *to* them.** "Users of MeetingMind will find that..." creates distance. It reads like a third-party observer describing a product rather than an invitation.
#
# ---
#
# ### 3. Persuasiveness — **Grade: C-**
#
# **Problems identified:**
#
# - **No emotional hook.** The description never taps into the real pain: meetings are exhausting, notes get lost, action items fall through the cracks, and people leave calls confused about what was decided. Starting with the pain makes the solution feel necessary.
# - **No social proof, numbers, or specifics.** Claims like "significant value-add propositions" and "granular productivity metrics" mean nothing without evidence. How much time does MeetingMind save? What percentage of action items are typically missed without it?
# - **Benefits are buried under features.** The description leans heavily on *what the product does* (transcription, sentiment analysis, dashboards) but rarely explains *why that matters* to the reader's daily work life.
# - **The "enterprise-ready" and "scalable" claims are unearned.** These are asserted without any supporting detail, making them feel like filler rather than genuine selling points.
# - **No sense of urgency or differentiation.** Why MeetingMind over competitors? What makes it *different*? The description gives no reason to choose this product specifically.
#
# ---
#
# ### Summary of Key Improvements Needed
#
# | Issue | Fix |
# |---|---|
# | Jargon-heavy language | Use plain, direct language |
# | Abstract feature descriptions | Show concrete outcomes and workflows |
# | No emotional connection | Open with relatable user pain |
# | Generic CTA | Write a specific, benefit-driven call to action |
# | No proof points | Add numbers or concrete claims |
# | Passive, distant tone | Shift to direct second-person address |
# | No brand voice | Add personality — helpful, confident, human |
#
# ---
#
# ## DRAFT 2: Improved Product Description
#
# **MeetingMind — Never Lose a Meeting Again**
#
# You've been there. The meeting ends, everyone nods, and within 48 hours nobody can agree on who was supposed to do what. Notes are incomplete, action items are forgotten, and half the team is already asking for a recap.
#
# **MeetingMind fixes that.**
#
# MeetingMind is an AI meeting assistant that sits quietly in the background of your calls and does the work you shouldn't have to do manually. It listens, understands, and delivers everything your team needs before anyone's even closed their laptop.
#
# **Here's what you get after every single meeting:**
#
# - ✅ **A clean, accurate transcript** — searchable, shareable, and timestamped so you can find exactly what was said and when
# - ✅ **Auto-generated action items** — assigned by name, with deadlines, pushed directly to Slack, Asana, or your tool of choice
# - ✅ **A plain-English summary** — the key decisions, the open questions, and the next steps, written so clearly that even people who missed the call feel caught up in 60 seconds
# - ✅ **Engagement insights** — see who's driving the conversation, where energy dropped, and how to run your next meeting more effectively
#
# MeetingMind works inside Zoom, Microsoft Teams, and Google Meet — no extra software, no friction, no learning curve. Most teams are up and running in under five minutes.
#
# **The result?** Our users report saving an average of 4.5 hours per week previously spent on manual notes and follow-up emails. More importantly, they report fewer dropped tasks, faster decisions, and meetings that actually lead somewhere.
#
# Whether you're a five-person startup or a 5,000-person enterprise, MeetingMind scales to fit your team — with bank-grade security and full compliance with GDPR and SOC 2 standards, so your conversations stay private.
#
# **Start your free 14-day trial today.** No credit card required. Your next meeting could be the first one where nothing falls through the cracks.
#
# ---
#
# ## COMPARISON: What Changed and Why
#
# | Element | Draft 1 | Draft 2 | Reason |
# |---|---|---|---|
# | **Opening** | Dense technical definition | Relatable pain scenario | Emotional hooks engage readers immediately |
# | **Sentence length** | Avg. 35+ words | Avg. 18 words | Shorter sentences improve readability and pace |
# | **Feature framing** | Listed abstractly | Each tied to a clear outcome | Benefits-first framing is more persuasive |
# | **Tone** | Cold, corporate | Warm, direct, human | Builds trust and brand personality |
# | **Proof points** | None | "4.5 hours saved per week" | Specifics are credible; vague claims are not |
# | **CTA** | Generic ("unlock potential") | Specific ("14-day free trial, no credit card") | Reduces friction and gives a clear next step |
# | **Second-person use** | Minimal ("users will find") | Consistent ("you," "your team") | Direct address creates connection |
# | **Jargon** | Heavy ("cognitive bandwidth," "tech stack") | Eliminated or plain-language replaced | Clarity over cleverness |
#
# ---
#
# *The core lesson: great product copy earns attention with empathy, holds it with clarity, and converts it with specificity. Technical capability is only persuasive once the reader already cares — and they only care when they see themselves in the problem being solved.*

# %% [markdown]
# Notice how the model tries to do everything in one pass. The "critique" is shallow because the model already committed to the description and doesn't want to contradict itself. The "rewrite" barely changes anything.
#
# This *kind of* works for simple tasks, but the model has no way to:
# - **Separate generation from evaluation** — it critiques its own work in the same breath
# - **Actually improve** — the critique and rewrite are performative, not substantive
# - **Debug** — if the final copy is bad, which step failed?
#
# For anything beyond toy examples, we need **structure**.

# %% [markdown]
# ## LangGraph: Graphs as a better abstraction
#
# LangGraph models workflows as **directed graphs**:
# - **Nodes** = individual processing steps (each does one focused thing)
# - **Edges** = connections that pass state between steps
# - **State** = a typed dictionary that carries context through the graph
#
# Let's rebuild the same task as a 3-node graph.

# %% [markdown]
# ## Side-by-side comparison

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END


class WorkflowState(TypedDict):
    product_name: str
    draft: str
    critique: str
    final_copy: str


def generate_node(state: WorkflowState) -> dict:
    """Step 1: Write an initial product description."""
    response = llm.invoke(
        f"Write a compelling product description (2-3 paragraphs) for a fictional "
        f"AI-powered tool called '{state['product_name']}'. "
        f"It's an AI meeting assistant that joins video calls, takes notes, "
        f"identifies action items, and sends follow-up summaries."
    )
    return {"draft": response.content}

# I can pick and choose the model I want for each step
critique_llm = ChatOpenAI(
    model="minimax/minimax-m2.5",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
)

def critique_node(state: WorkflowState) -> dict:
    """Step 2: Critically evaluate the draft — separate LLM call, fresh perspective."""
    response = critique_llm.invoke(
        f"You are a senior copywriter reviewing a junior writer's work. "
        f"Critique this product description for:\n"
        f"- **Clarity**: Is it easy to understand? Any jargon or vague claims?\n"
        f"- **Tone**: Is it professional yet engaging? Too salesy or too flat?\n"
        f"- **Persuasiveness**: Does it make you want to try the product? What's missing?\n\n"
        f"Be specific and constructive. Point to exact phrases that need improvement.\n\n"
        f"Product description:\n{state['draft']}"
    )
    return {"critique": response.content}


def refine_node(state: WorkflowState) -> dict:
    """Step 3: Rewrite the description incorporating the critique."""
    response = llm.invoke(
        f"Rewrite this product description, addressing every point in the critique below. "
        f"Keep what works, fix what doesn't.\n\n"
        f"Original draft:\n{state['draft']}\n\n"
        f"Critique:\n{state['critique']}\n\n"
        f"Rewritten description:"
    )
    return {"final_copy": response.content}


# Build the graph
graph = StateGraph(WorkflowState)
graph.add_node("generate", generate_node)
graph.add_node("critique", critique_node)
graph.add_node("refine", refine_node)

graph.add_edge(START, "generate")
graph.add_edge("generate", "critique")
graph.add_edge("critique", "refine")
graph.add_edge("refine", END)

app = graph.compile()

# %%
# Visualize the graph topology
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))

# %%
# Run it
result = app.invoke({"product_name": "MeetingMind"})

print("=== Draft ===")
print(result["draft"])
print("\n=== Critique ===")
print(result["critique"])
print("\n=== Final Copy ===")
print(result["final_copy"])
# Out:
# === Draft ===
# # MeetingMind: Never Miss What Matters
#
# Say goodbye to frantic note-taking and forgotten follow-ups. **MeetingMind** is your intelligent meeting companion that joins every video call — on Zoom, Teams, Google Meet, and beyond — and works quietly in the background so you can focus on what you actually showed up to do: think, collaborate, and make decisions. Powered by advanced conversational AI, MeetingMind doesn't just transcribe words; it *understands context*, capturing the nuance behind discussions, flagging key decisions the moment they're made, and distinguishing genuine commitments from casual conversation.
#
# What truly sets MeetingMind apart is its razor-sharp action item detection. As your meeting unfolds, MeetingMind identifies who said they'd do what — and by when — assigning ownership automatically and building a structured task list in real time. Within minutes of the call ending, every participant receives a crisp, human-readable summary delivered straight to their inbox: key discussion points, decisions reached, open questions, and a clear accountability list so nothing slips through the cracks. It even integrates directly with tools like Slack, Notion, Asana, and Jira, pushing tasks where your team already works.
#
# MeetingMind doesn't just save time — it fundamentally changes meeting culture. Teams that use it report **fewer redundant check-ins, stronger accountability, and meetings that actually end with clarity**. Whether you're running a 10-person startup or coordinating across a global enterprise, MeetingMind turns every conversation into a documented, actionable record. Your best meeting might just be the one you stop scrambling through.
#
# === Critique ===
# # Copy Critique: MeetingMind Product Description
#
# ## Clarity — 7/10
#
# **What's working:** The core value proposition comes through clearly — this is an AI meeting assistant that transcribes, summarizes, and tracks action items. The supported platforms (Zoom, Teams, Google Meet) and integrations (Slack, Notion, Asana, Jira) are specific and helpful.
#
# **Issues to address:**
#
# - **"understands context" / "capturing the nuance behind discussions"** — These are vague, jargon-heavy claims. What does "understanding context" actually look like in practice? *Suggestion: Replace with a concrete example, e.g., "It recognizes when a passing comment becomes a real commitment."*
#
# - **"distinguishing genuine commitments from casual conversation"** — This is a strong differentiator, but it reads as a promise rather than an explanation. Consider: *"...and knows the difference between 'we should look into that' and 'Sarah will own this by Friday.'"
#
# - **"crisp, human-readable summary"** — "Human-readable" is industry jargon that doesn't mean much to users. What makes it better than a raw transcript? *Be specific: it groups points by topic, surfaces decisions in bold, etc.*
#
# - **"works quietly in the background"** — This phrase is filler. It doesn't add meaningful information.
#
# ---
#
# ## Tone — 6.5/10
#
# **What's working:** The opening line immediately addresses a real pain point ("frantic note-taking and forgotten follow-ups"). The professional language is accessible and doesn't overcorrect into casual territory.
#
# **Issues to address:**
#
# - **Overuse of marketing superlatives** — Phrases like "razor-sharp action item detection" and "fundamentally changes meeting culture" feel夸张 (over-the-top) and undercut credibility. *Revision: "accurately detects action items" and "improves meeting culture."*
#
# - **Cliché ending:** "Your best meeting might just be the one you stop scrambling through" — This tries too hard to be clever and ends up feeling like a LinkedIn caption. *Consider a more grounded closer: "Try MeetingMind free for 14 days and see what you're missing."*
#
# - **"nothing slips through the cracks"** — Trite. Every SaaS product uses this phrase.
#
# **Verdict:** The tone is *too salesy* in places. Pull back on the hyperbole and let the features speak for themselves.
#
# ---
#
# ## Persuasiveness — 6/10
#
# **What's working:** The description does a solid job of explaining *what* the product does and *why* it matters. The integration list is specific (users know immediately if it fits their stack). The mention of accountability and clarity as outcomes resonates with the target audience.
#
# **What's missing:**
#
# 1. **Social proof** — No user testimonials, case studies, or metrics ("Teams report 30% fewer follow-up meetings"). Without this, claims like "fundamentally changes meeting culture" feel unsupported.
#
# 2. **Specific benefits, not just features** — How much time does this save? *Example: "Recapture 20+ hours per month spent on note-taking and follow-ups."*
#
# 3. **Pricing or friction-reducer** — No mention of a free trial, freemium tier, or starting price. Readers don't know how to take the next step.
#
# 4. **Differentiation** — Several AI meeting assistants exist (Otter.ai, Fireflies, Gong). What makes MeetingMind the choice? The "context understanding" and "genuine vs. casual conversation" claims are start, but they need weight — user data, a unique workflow, or a proprietary model.
#
# 5. **Clear CTA** — The description ends with a philosophical statement. It should end with a *command*: "Start your free trial" or "Book a demo."
#
# ---
#
# ## Summary
#
# | Dimension | Score | Top Priority |
# |-----------|-------|--------------|
# | Clarity | 7/10 | Replace vague claims ("understands context") with concrete examples |
# | Tone | 6.5/10 | Cut the superlatives and cliché ending |
# | Persuasiveness | 6/10 | Add social proof, specific metrics, and a clear CTA |
#
# **Overall:** This is a strong first draft. The writer clearly understands the product and the audience's pain points. The fix is in the refinement — tightening the language, grounding the claims, and letting credibility do the selling.
#
# === Final Copy ===
# # MeetingMind: Never Miss What Matters
#
# Say goodbye to frantic note-taking and forgotten follow-ups. **MeetingMind** is your intelligent meeting companion that joins every video call — on Zoom, Teams, Google Meet, and beyond — so you can focus on what you actually showed up to do: think, collaborate, and make decisions.
#
# Most meeting tools record what was said. MeetingMind tracks what was decided. It knows the difference between *"we should look into that"* and *"Sarah will own this by Friday"* — catching the moment a passing comment becomes a real commitment, and making sure it doesn't disappear when the call ends.
#
# As your meeting unfolds, MeetingMind identifies who said they'd do what — and by when — assigning ownership automatically and building a structured task list in real time. Within minutes of the call ending, every participant receives a summary delivered straight to their inbox: discussion points grouped by topic, decisions called out clearly, open questions flagged, and a full accountability list. No hunting through a transcript. No he-said-she-said on Monday morning.
#
# It also integrates directly with Slack, Notion, Asana, and Jira, pushing tasks where your team already works — so nothing gets lost in the handoff between the meeting and the actual work.
#
# Teams using MeetingMind report **30% fewer follow-up check-ins** and recapture an average of **20+ hours per month** previously lost to note-taking, recap emails, and chasing down action items. Startups use it to move faster. Enterprise teams use it to stay aligned across time zones. Both use it because it works.
#
# > *"We stopped sending meeting recap emails entirely. MeetingMind just handles it."*
# > — Operations Lead, Series B SaaS company
#
# **Try MeetingMind free for 14 days — no credit card required.** See what your team has been missing.
