# %% [markdown]
# # Tools and ReAct Agents
#
#
# This notebook covers tool integration and the ReAct pattern at three levels of abstraction:
# 1. **LangChain** — `create_agent` with middleware support
# 2. **Manual** — build ReAct from scratch with `StateGraph`
#
# Plus: MCP (Model Context Protocol) integration for external tools.

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
# Expects: OPENROUTER_API_KEY, SERPAPI_API_KEY
# Optional: LANGSMITH_API_KEY
# Out:
# True

# %% [markdown]
# ## 1. Defining tools
#
# Tools are functions the LLM can call. We use the `@tool` decorator to register them with a name, description, and typed arguments. The LLM sees the description and decides when/how to call each tool.

# %%
from langchain_core.tools import tool
# StructuredTool is another option
from langchain_community.utilities import SerpAPIWrapper


@tool
def calculator(expression: str) -> str:
    """Evaluate a mathematical expression. Use this for any math calculations."""
    try:
        return str(eval(expression))
    except Exception as e:
        return f"Error: {e}"


@tool
def get_current_date() -> str:
    """Get today's date. Use this when the user asks about today or the current date."""
    from datetime import date
    return str(date.today())


@tool
def web_search(query: str) -> str:
    """Search the web for real-time information. Use this for current events, facts, or any question requiring up-to-date knowledge."""
    serpapi = SerpAPIWrapper()
    return serpapi.run(query)
    # optionally, I could parse the result and return something different


tools = [calculator, get_current_date, web_search]

# Each tool has a name and description the LLM can read
for t in tools:
    print(f"{t.name}: {t.description[:80]}")
# Out:
# calculator: Evaluate a mathematical expression. Use this for any math calculations.
# get_current_date: Get today's date. Use this when the user asks about today or the current date.
# web_search: Search the web for real-time information. Use this for current events, facts, or

# %% [markdown]
# ## 2. Prebuilt ReAct agent (`create_agent`)
#
# The fastest way to get a tool-calling agent running. Under the hood, this creates a `StateGraph` with two nodes ("agent" and "tools") and a conditional edge that loops until the LLM stops calling tools.

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from IPython.display import Image, display

llm = ChatOpenAI(
    model="qwen/qwen3.7-max",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
)

agent = create_agent(llm, tools)

# Visualize — two nodes: agent (LLM) and tools (executor)
display(Image(agent.get_graph().draw_mermaid_png()))

# %%
# Test: requires calculator tool
result = agent.invoke({"messages": [("user", "What is 247 * 38?")]})

for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is 247 * 38?
# ================================== Ai Message ==================================
# Tool Calls:
#   calculator (call_91fd3b93e1b54f519f27e7d5)
#  Call ID: call_91fd3b93e1b54f519f27e7d5
#   Args:
#     expression: 247 * 38
# ================================= Tool Message =================================
# Name: calculator
#
# 9386
# ================================== Ai Message ==================================
#
# 247 times 38 equals **9,386**.

# %%
result["messages"][3]
# Out:
# AIMessage(content='247 times 38 equals **9,386**.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 106, 'prompt_tokens': 465, 'total_tokens': 571, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 86, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0.001937925, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.0019575, 'upstream_inference_prompt_cost': 0.0011625, 'upstream_inference_completions_cost': 0.000795}}, 'model_provider': 'openai', 'model_name': 'qwen/qwen3.7-max-20260520', 'system_fingerprint': None, 'id': 'gen-1779457888-IgLzroJIBypFU9i8gEym', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e4ff4-92ba-7f41-9c1d-4bb554f07a81-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 465, 'output_tokens': 106, 'total_tokens': 571, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 86}})

# %%
# Test: requires search tool
result = agent.invoke({"messages": [("user", "What was the latest LangChain release?")]})

for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What was the latest LangChain release?
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_2be9a206d3be43dabd50a902)
#  Call ID: call_2be9a206d3be43dabd50a902
#   Args:
#     query: latest LangChain release 2025
# ================================= Tool Message =================================
# Name: web_search
#
# ['langgraph v1.2.0. This release adds finer-grained control over node execution (timeouts, error recovery, and graceful shutdown), a new channel type that ...', 'Latest version. Released: May 15, 2026. Building applications with LLMs through composability. Navigation. Project description; Release history; Download files ...', 'langchain-core==1.4.0 Latest · Latest. Changes since langchain-core==0.3 ... release(langchain): release 0.3.30 (#37241) chore(langchain): backport loads ...', 'It brings Insights , the... December 2025. LangSmith. v0.12.61. December 17, 2025. Pairwise annotation queues for comparing agent outputs. Pairwise Annotation ...', "LangChain's come a long way since last year. It's way smoother now for chaining stuff, but it can still feel a bit bulky if your needs are simple.", 'The new standard for building agents in LangChain, replacing langgraph.prebuilt.create_react_agent . Standard content blocks.', 'In February 2024 LangChain released LangSmith, a closed-source observability ... In April 2025, LangChain was featured in the Forbes AI 50 list.', 'This is a four course that will take you from the assumption that you know nothing about Lang chain to being able to proficiently use the framework.', 'Description. LangChain is a framework for building LLM-powered applications. Prior to @langchain/core versions 0.3.80 and 1.1.8, ...', 'Released in October 2025, LangChain 1.0 represents a fundamental shift toward stability and simplicity. The core philosophy? Streamline the ...']
# ================================== Ai Message ==================================
#
# Based on my search, here's what I found regarding the latest LangChain releases:
#
# ### **LangChain 1.0** (October 2025)
# This was the landmark major release, described as **"a fundamental shift toward stability and simplicity."** The core philosophy was to streamline the framework.
#
# ### Subsequent Package Releases
# LangChain is now split into multiple packages, each with their own versioning:
#
# | Package | Latest Version |
# |---|---|
# | **langchain-core** | `1.4.0` |
# | **langchain** | `0.3.30` |
# | **langgraph** | `1.2.0` |
# | **@langchain/core** (JS) | `1.1.8` |
#
# ### Other Notable Updates
# - **LangSmith v0.12.61** (December 2025) — Added pairwise annotation queues for comparing agent outputs.
# - A new standard for building agents in LangChain, replacing `langgraph.prebuilt.create_react_agent`, with standard content blocks.
# - LangChain was featured in the **Forbes AI 50** list in April 2025.
#
# The **LangChain 1.0 release in October 2025** was the biggest milestone, representing the project's move toward a more stable and production-ready API. For the very latest patch versions, you can check their [PyPI page](https://pypi.org/project/langchain/) or [GitHub releases](https://github.com/langchain-ai/langchain/releases).

# %%
# Test: requires date tool + search
result = agent.invoke({"messages": [("user", "What's today's date, and what happened in AI news today?")]})

for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's today's date, and what happened in AI news today?
# ================================== Ai Message ==================================
#
# Let me get today's date and search for the latest AI news for you.
# Tool Calls:
#   get_current_date (call_2b8a163b31bb4d01a68cc145)
#  Call ID: call_2b8a163b31bb4d01a68cc145
#   Args:
#   web_search (call_4d2c39d7a1e84065b6c58c6e)
#  Call ID: call_4d2c39d7a1e84065b6c58c6e
#   Args:
#     query: AI news today
# ================================= Tool Message =================================
# Name: get_current_date
#
# 2026-05-22
# ================================= Tool Message =================================
# Name: web_search
#
# [{"title": "Six search engines worth trying now that Google isn’t really Google anymore", "link": "https://techcrunch.com/2026/05/21/six-search-engines-worth-trying-now-that-google-isnt-really-google-anymore/", "source": "TechCrunch", "source_logo": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/Lq7UF-o5-aEOfn24F6F7lPyOVxT18vwEyQp0EaZk-N4.jpeg", "date": "19 hours ago", "thumbnail": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/zO2HCfcQz3welm7wrnLZHuuvuA8Iri3CoF9feJ6M8rc.jpeg"}, {"title": "Governor Newsom signs first-of-its-kind executive order to prepare workers and businesses for potential AI disruption", "link": "https://www.gov.ca.gov/2026/05/21/governor-newsom-signs-first-of-its-kind-executive-order-to-prepare-workers-and-businesses-for-potential-ai-disruption/", "source": "California State Portal | CA.gov", "source_logo": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/u6NDna9kGAP8u1jokEkd-NXNIGq4jkdmH5jXDHK8GsE.png", "date": "16 hours ago", "thumbnail": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/zyl-dHEupjEYiTOBuApqZ1lrQNraGJMLpWEm2qQv9Bs.jpeg"}, {"title": "Futures Rise; 5 AI Stocks Flash Buy Signals", "link": "https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-oil-prices-amazon-credo-ai-stocks-buy/", "source": "Investor's Business Daily", "source_logo": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/Bz4KSQc4znQQyfzaY6bM9HGKIxcjEyhPBYF0ElLRj30.png", "date": "2 hours ago", "thumbnail": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/X9stLHASWKdLGfxWg88QYAxDrOE1bC_tVrU5uLGeUtc.jpeg"}, {"title": "Trump abruptly halts signing AI order citing concerns with overregulating", "link": "https://www.usatoday.com/story/news/politics/2026/05/21/trump-ai-executive-order/90194199007/", "source": "USA Today", "source_logo": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/4_tj0U6-7phk2lWrJZ2yuttonxNsqBlCfX41PFAw2fc.png", "date": "17 hours ago", "thumbnail": "https://serpapi.com/searches/6a105f7c974bbbb4b75c3fae/images/AuvLbxf4UgmaDJl07eiAnJWv8P7jpLx6eD51CgtC9rE.jpeg"}]
# ================================== Ai Message ==================================
#
# Today is **May 22, 2026**.
#
# Here are the top AI headlines from today and overnight:
#
# *   **Federal Policy:** President Trump abruptly halted the signing of an executive order on AI, citing concerns about overregulating the industry.
# *   **California Workforce:** In contrast to the federal move, Governor Gavin Newsom signed a first-of-its-kind executive order aimed at preparing California workers and businesses for potential disruption caused by AI.
# *   **AI Market:** AI stocks are drawing attention as five specific companies are flashing buy signals.
# *   **Search Landscape:** TechCrunch is highlighting that as Google changes due to AI integration, several alternative search engines are becoming viable options for users.

# %% [markdown]
# ## 3. ReAct agent from scratch (manual StateGraph)
#
# Understanding the internals is essential for customization. Let's build the same agent manually:
# - `AgentState` with `add_messages` reducer
# - `call_model` node — invokes the LLM with tool bindings
# - `tool_node` — executes tool calls from the LLM's response
# - `should_continue` — routes to tools or END based on whether the LLM made tool calls

# %%
from typing import Annotated, Sequence, TypedDict
from langchain_core.messages import BaseMessage, ToolMessage
from langgraph.graph.message import add_messages
from langgraph.graph import StateGraph, END, START


class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], add_messages]


# Bind tools to the LLM so it knows what's available
llm_with_tools = llm.bind_tools(tools)

# Map tool names to tool objects for execution
tools_by_name = {t.name: t for t in tools}


def should_continue(state: AgentState) -> str:
    """If the last message has tool calls, route to tools. Otherwise, end."""
    last_message = state["messages"][-1]
    if hasattr(last_message, "tool_calls") and last_message.tool_calls:
        return "tools"
    return "end"


def call_model(state: AgentState) -> dict:
    """Invoke the LLM with the current message history."""
    response = llm_with_tools.invoke(state["messages"])
    return {"messages": [response]}


def tool_node(state: AgentState) -> dict:
    """Execute each tool call from the last AI message."""
    outputs = []
    for tool_call in state["messages"][-1].tool_calls:
        result = tools_by_name[tool_call["name"]].invoke(tool_call["args"])
        outputs.append(
            ToolMessage(content=str(result), tool_call_id=tool_call["id"])
        )
    return {"messages": outputs}


# Build the graph
graph = StateGraph(AgentState)
graph.add_node("agent", call_model)
graph.add_node("tools", tool_node)

graph.add_edge(START, "agent")
graph.add_conditional_edges(
    "agent",
    should_continue,
    {"tools": "tools", "end": END},
)
graph.add_edge("tools", "agent")  # After tools run, go back to the LLM

manual_agent = graph.compile()

# %%
# The manual graph should look identical to the prebuilt one
display(Image(manual_agent.get_graph().draw_mermaid_png()))

# %%
# Test: same question, same result
result = manual_agent.invoke({"messages": [("user", "What is 247 * 38?")]})

for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is 247 * 38?
# ================================== Ai Message ==================================
# Tool Calls:
#   calculator (call_8d34a25e572a40318118f8b7)
#  Call ID: call_8d34a25e572a40318118f8b7
#   Args:
#     expression: 247 * 38
# ================================= Tool Message =================================
#
# 9386
# ================================== Ai Message ==================================
#
# 247 × 38 = **9,386**

# %% [markdown]
# The prebuilt and manual versions produce the same graph topology. The manual version gives you full control to customize the agent loop — add logging, modify tool results, inject system prompts, etc.

# %% [markdown]
# ## 4. MCP integration
#
# [Model Context Protocol (MCP)](https://modelcontextprotocol.io/) lets you load tools from external servers. The `langchain-mcp-adapters` package converts MCP tools into LangChain tools that work with any agent.
#
# We have a custom MCP server in `mcp_server.py` with three tools: `add`, `multiply`, and `web_search`. Let's load it and combine those tools with our native tools.

# %%
import sys
from langchain_mcp_adapters.client import MultiServerMCPClient

# Point to our custom MCP server — it exposes add, multiply, and web_search tools
mcp_server_path = os.path.join(os.path.dirname(os.path.abspath("__file__")), "mcp_server.py")

client = MultiServerMCPClient(
    {
        "course_tools": {
            "command": sys.executable,  # Use the current Python interpreter
            "args": [mcp_server_path],
            "transport": "stdio",
        }
    }
)

# %%
# As of langchain-mcp-adapters 0.1.0, no context manager needed — just await get_tools()
mcp_tools = await client.get_tools()

print(f"Loaded {len(mcp_tools)} MCP tools:")
for t in mcp_tools:
    print(f"  {t.name}: {t.description[:60]}")
# Out:
# Loaded 3 MCP tools:
#   add: Add two numbers together. Use this for addition calculations
#   multiply: Multiply two numbers together. Use this for multiplication c
#   web_search: Search the web for real-time information. Use this for any f

# %%
# Combine native tools (calculator, date) with MCP tools (add, multiply, web_search)
all_tools = [calculator, get_current_date] + mcp_tools
print(f"Total tools available: {len(all_tools)}")

# Build an agent with all tools
from langchain.agents import create_agent
combined_agent = create_agent(llm, all_tools)

# Test with MCP's add tool
print("\n--- Test: MCP add tool ---")
result = await combined_agent.ainvoke(
    {"messages": [("user", "Add 42 and 58 using the add tool")]}
)
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# Total tools available: 5
#
# --- Test: MCP add tool ---
# ================================ Human Message =================================
#
# Add 42 and 58 using the add tool
# ================================== Ai Message ==================================
# Tool Calls:
#   add (call_b7ed57cc56d34a27806abf79)
#  Call ID: call_b7ed57cc56d34a27806abf79
#   Args:
#     a: 42
#     b: 58
# ================================= Tool Message =================================
# Name: add
#
# [{'type': 'text', 'text': '100', 'id': 'lc_466cd253-b443-4013-9bb4-1bcf364b9e73'}]
# ================================== Ai Message ==================================
#
# The sum of 42 and 58 is **100**.

# %%
# Test with MCP's multiply tool
print("--- Test: MCP multiply tool ---")
result = await combined_agent.ainvoke(
    {"messages": [("user", "Multiply 7 and 13")]}
)
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# --- Test: MCP multiply tool ---
# ================================ Human Message =================================
#
# Multiply 7 and 13
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_a3dc55c717694194897d46a4)
#  Call ID: call_a3dc55c717694194897d46a4
#   Args:
#     a: 7
#     b: 13
# ================================= Tool Message =================================
# Name: multiply
#
# [{'type': 'text', 'text': '91', 'id': 'lc_4f712a30-d25e-480f-a735-5c752d274854'}]
# ================================== Ai Message ==================================
#
# 7 × 13 = **91**

# %% [markdown]
# The key insight: MCP tools are just LangChain tools once loaded. You can mix them freely with `@tool` functions, and the LLM treats them identically.
#
# ---
#
# **Summary:**
# - `@tool` decorator defines tools with typed arguments and descriptions
# - `create_agent` (prebuilt) — fastest path to a working agent
# - `create_agent` (LangChain 1.0) — same API, supports middleware (notebook 5)
# - Manual `StateGraph` — full control over the agent loop
# - MCP — load external tools from any MCP server
#
# Next: we'll use tools inside a **RAG workflow** with conditional routing.
